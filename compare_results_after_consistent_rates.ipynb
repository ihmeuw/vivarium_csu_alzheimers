# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from vivarium import Artifact

# !date
# Out:
# Tue Oct 21 10:34:32 PDT 2025

# %%
# !ls -halt /home/abie/vivarium_results/united_states_of_america/2025_10_20_18_01_36/results
# !ls -halt /home/abie/vivarium_results/united_states_of_america/2025_10_20_17_15_09/results
# Out:
# total 336K
# drwxrwxr-x 3 abie abie 4.0K Oct 20 18:54 ..
# -rw-rw-r-- 1 abie abie  12K Oct 20 18:54 transition_count_alzheimers_disease_and_other_dementias.parquet
# drwxrwxr-x 2 abie abie 4.0K Oct 20 18:54 .
# -rw-rw-r-- 1 abie abie  30K Oct 20 18:54 person_time_alzheimers_disease_and_other_dementias.parquet
# -rw-rw-r-- 1 abie abie  31K Oct 20 18:54 ylls.parquet
# -rw-rw-r-- 1 abie abie  12K Oct 20 18:54 deaths.parquet
# -rw-rw-r-- 1 abie abie  59K Oct 20 18:54 ylds.parquet
# -rw-rw-r-- 1 abie abie  19K Oct 20 18:54 transition_count_treatment.parquet
# -rw-rw-r-- 1 abie abie  51K Oct 20 18:54 person_time_treatment.parquet
# -rw-rw-r-- 1 abie abie  41K Oct 20 18:54 person_time_ever_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie abie  13K Oct 20 18:54 person_time_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie abie  12K Oct 20 18:54 counts_newly_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie abie  11K Oct 20 18:54 counts_bbbm_tests.parquet
# ...

# %%
dir_old = '/home/abie/vivarium_results/united_states_of_america/2025_10_20_17_15_09/results'
dir_new = '/home/abie/vivarium_results/united_states_of_america/2025_10_20_18_01_36/results'

# %%
df_old = pd.read_parquet(dir_old + '/person_time_alzheimers_disease_and_other_dementias.parquet')
df_new = pd.read_parquet(dir_new + '/person_time_alzheimers_disease_and_other_dementias.parquet')
# df_new

# %%
for df in df_new, df_old:
    df.query("sub_entity == 'alzheimers_disease_state' and event_year == '2025'").groupby('age_group').value.sum().plot(marker='o')
# Out:
# /tmp/ipykernel_91867/1481622640.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.query("sub_entity == 'alzheimers_disease_state' and event_year == '2025'").groupby('age_group').value.sum().plot(marker='o')
# /tmp/ipykernel_91867/1481622640.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.query("sub_entity == 'alzheimers_disease_state' and event_year == '2025'").groupby('age_group').value.sum().plot(marker='o')
